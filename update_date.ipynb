# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import requests
import json
import time

# %%
web_591_url = 'https://rent.591.com.tw/?kind=0&region=3'

headers = {'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/99.0.4844.51 Safari/537.36'}
url = requests.get(web_591_url, headers = headers).url
driver = webdriver.Chrome(executable_path=r"C:\Users\User\Desktop\python\591_test\chromedriver.exe")
driver.get(url)

element = driver.find_element_by_xpath('//*[@id="rent-list-app"]/div/div[3]/div/section[3]/div')

# %%
html_text = element.text.split('元/月\n')

# %%
web591_info = {}
web591_info_list = []

for i in range(len(html_text)):
    building_type = html_text[i].split('\n')[2].split(' ')[0]
    building_layout = ' '.join(html_text[i].split('\n')[2].split(' ')[1:])
    renter = html_text[i].split('\n')[5].split(' ')[0]
    name = html_text[i].split('\n')[5].split(' ')[1]
    rent = html_text[i].split('\n')[6]
    region = '新北'
    title = html_text[i].split('\n')[0]
    if '限女性' in title:
        requirement = '限女性'
    elif '限男性' in title:
        requirement = '限男性'
    else:
        requirement = '男女生皆可'
        
    web591_info = {'出租者' : name,
                   '出租者身份': renter,
                   '聯絡電話' : '090000' + str(i),
                   '型態' : '公寓',
                   '現況' : building_type,
                   '格局' : building_layout,
                   '性別要求' : requirement,
                   '區域' : region
                  }
    web591_info_list.append(web591_info)

web591_info_list
# Out:
# [{'出租者': '李先生',
#   '出租者身份': '代理人',
#   '聯絡電話': '0900000',
#   '型態': '公寓',
#   '現況': '分租套房',
#   '格局': '9坪 4F/5F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '李先生',
#   '出租者身份': '屋主',
#   '聯絡電話': '0900001',
#   '型態': '公寓',
#   '現況': '獨立套房',
#   '格局': '11坪 4F/5F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '鄭先生',
#   '出租者身份': '屋主',
#   '聯絡電話': '0900002',
#   '型態': '公寓',
#   '現況': '整層住家',
#   '格局': '3房2廳 30坪 4F/11F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '游先生',
#   '出租者身份': '屋主',
#   '聯絡電話': '0900003',
#   '型態': '公寓',
#   '現況': '雅房',
#   '格局': '6坪 頂樓加蓋/4F',
#   '性別要求': '限女性',
#   '區域': '新北'},
#  {'出租者': '洪先生',
#   '出租者身份': '屋主',
#   '聯絡電話': '0900004',
#   '型態': '公寓',
#   '現況': '獨立套房',
#   '格局': '6坪 4F/5F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '周小姐',
#   '出租者身份': '代理人',
#   '聯絡電話': '0900005',
#   '型態': '公寓',
#   '現況': '雅房',
#   '格局': '4坪 2F/5F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '林先生',
#   '出租者身份': '屋主',
#   '聯絡電話': '0900006',
#   '型態': '公寓',
#   '現況': '分租套房',
#   '格局': '6坪 4F/5F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '簡先生',
#   '出租者身份': '屋主',
#   '聯絡電話': '0900007',
#   '型態': '公寓',
#   '現況': '獨立套房',
#   '格局': '10坪 5F/5F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '黃先生',
#   '出租者身份': '屋主',
#   '聯絡電話': '0900008',
#   '型態': '公寓',
#   '現況': '獨立套房',
#   '格局': '8坪 4F/5F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '洪先生',
#   '出租者身份': '屋主',
#   '聯絡電話': '0900009',
#   '型態': '公寓',
#   '現況': '獨立套房',
#   '格局': '6坪 4F/5F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '王先生',
#   '出租者身份': '代理人',
#   '聯絡電話': '09000010',
#   '型態': '公寓',
#   '現況': '獨立套房',
#   '格局': '6坪 4F/5F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '李先生',
#   '出租者身份': '仲介',
#   '聯絡電話': '09000011',
#   '型態': '公寓',
#   '現況': '整層住家',
#   '格局': '4房2廳 52.6坪 6F/15F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '765公尺',
#   '出租者身份': '距板橋站',
#   '聯絡電話': '09000012',
#   '型態': '公寓',
#   '現況': '屋主直租',
#   '格局': '近捷運 拎包入住 隨時可遷入 可開伙 可養寵物',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '黃太太',
#   '出租者身份': '代理人',
#   '聯絡電話': '09000013',
#   '型態': '公寓',
#   '現況': '獨立套房',
#   '格局': '10坪 5F/5F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '洪小姐',
#   '出租者身份': '代理人',
#   '聯絡電話': '09000014',
#   '型態': '公寓',
#   '現況': '整層住家',
#   '格局': '2房2廳 30坪 5F/5F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '孫先生',
#   '出租者身份': '屋主',
#   '聯絡電話': '09000015',
#   '型態': '公寓',
#   '現況': '獨立套房',
#   '格局': '6坪 2F/4F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '盧太太',
#   '出租者身份': '屋主',
#   '聯絡電話': '09000016',
#   '型態': '公寓',
#   '現況': '獨立套房',
#   '格局': '8坪 4F/5F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '劉先生',
#   '出租者身份': '代理人',
#   '聯絡電話': '09000017',
#   '型態': '公寓',
#   '現況': '分租套房',
#   '格局': '4.8坪 3F/4F',
#   '性別要求': '限女性',
#   '區域': '新北'},
#  {'出租者': '呂太太',
#   '出租者身份': '屋主',
#   '聯絡電話': '09000018',
#   '型態': '公寓',
#   '現況': '獨立套房',
#   '格局': '16坪 3F/4F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '李先生',
#   '出租者身份': '屋主',
#   '聯絡電話': '09000019',
#   '型態': '公寓',
#   '現況': '獨立套房',
#   '格局': '13.5坪 2F/4F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '楊小姐',
#   '出租者身份': '代理人',
#   '聯絡電話': '09000020',
#   '型態': '公寓',
#   '現況': '整層住家',
#   '格局': '5房2廳 36坪 6F/19F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '郭先生',
#   '出租者身份': '仲介',
#   '聯絡電話': '09000021',
#   '型態': '公寓',
#   '現況': '整層住家',
#   '格局': '2房1廳 19.9坪 6F/13F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '楊小姐',
#   '出租者身份': '代理人',
#   '聯絡電話': '09000022',
#   '型態': '公寓',
#   '現況': '整層住家',
#   '格局': '3房2廳 35坪 5F/19F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '陳小姐',
#   '出租者身份': '屋主',
#   '聯絡電話': '09000023',
#   '型態': '公寓',
#   '現況': '獨立套房',
#   '格局': '8坪 頂樓加蓋/5F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '陳小姐',
#   '出租者身份': '屋主',
#   '聯絡電話': '09000024',
#   '型態': '公寓',
#   '現況': '整層住家',
#   '格局': '3房1廳 18坪 2F/5F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '李小姐',
#   '出租者身份': '屋主',
#   '聯絡電話': '09000025',
#   '型態': '公寓',
#   '現況': '整層住家',
#   '格局': '2房1廳 20坪 5F/5F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '呂小姐',
#   '出租者身份': '屋主',
#   '聯絡電話': '09000026',
#   '型態': '公寓',
#   '現況': '雅房',
#   '格局': '4坪 5F/5F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '王先生',
#   '出租者身份': '屋主',
#   '聯絡電話': '09000027',
#   '型態': '公寓',
#   '現況': '獨立套房',
#   '格局': '7坪 1F/6F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '胡先生',
#   '出租者身份': '代理人',
#   '聯絡電話': '09000028',
#   '型態': '公寓',
#   '現況': '整層住家',
#   '格局': '1房0廳 8坪 4F/4F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'},
#  {'出租者': '趙小姐',
#   '出租者身份': '屋主',
#   '聯絡電話': '09000029',
#   '型態': '公寓',
#   '現況': '獨立套房',
#   '格局': '16.8坪 11F/19F',
#   '性別要求': '男女生皆可',
#   '區域': '新北'}]

# %%
import pymongo

# %%
myclient = pymongo.MongoClient("mongodb://localhost:27017/")
mydb = myclient["web591_db"]
mycol = mydb["sites"]

x = mycol.insert_many(web591_info_list)

# %%
dblist = myclient.list_database_names()

if "web591_db" in dblist:
    print("已存在！")
# Out:
# 已存在！
